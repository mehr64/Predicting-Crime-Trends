# %% [markdown]
# <a href="https://colab.research.google.com/github/mehr64/Predicting-Crime-Trends/blob/main/preprocessingforML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = pd.read_csv('/content/sample_data/cleaned_data.csv')
initial_statistics = data.describe()
initial_statistics
# Out:
#        Financial Quarter  Number of Offences
# count       98777.000000        98777.000000
# mean            2.405347          222.665226
# std             1.141996          861.620770
# min             1.000000            0.000000
# 25%             1.000000            1.000000
# 50%             2.000000           12.000000
# 75%             3.000000          105.000000
# max             4.000000        29480.000000

# %%
pd.set_option('display.max_columns', None)
# Display summary statistics for all columns
initial_statistics = data.describe(include='all')
initial_statistics
# Out:
#        Financial Year  Financial Quarter          Force Name  \
# count           98777       98777.000000               98777
# unique              5                NaN                  43
# top           2020/21                NaN  Greater Manchester
# freq            23220                NaN                2303
# mean              NaN           2.405347                 NaN
# std               NaN           1.141996                 NaN
# min               NaN           1.000000                 NaN
# 25%               NaN           1.000000                 NaN
# 50%               NaN           2.000000                 NaN
# 75%               NaN           3.000000                 NaN
# max               NaN           4.000000                 NaN
#
#                    Offence Description                Offence Group  \
# count                            98777                        98777
# unique                             145                            9
# top     Absconding from lawful custody  Violence against the person
# freq                               731                        23785
# mean                               NaN                          NaN
# std                                NaN                          NaN
# min                                NaN                          NaN
# 25%                                NaN                          NaN
# 50%                                NaN                          NaN
# 75%                                NaN                          NaN
# max                                NaN                          NaN
#
#                             Offence Subgroup Offence Code  Number of Offences
# count                                  98777        98777        98777.000000
# unique                                    25          145                 NaN
# top     Miscellaneous crimes against society           80                 NaN
# freq                                   17544          731                 NaN
# mean                                     NaN          NaN          222.665226
# std                                      NaN          NaN          861.620770
# min                                      NaN          NaN            0.000000
# 25%                                      NaN          NaN            1.000000
# 50%                                      NaN          NaN           12.000000
# 75%                                      NaN          NaN          105.000000
# max                                      NaN          NaN        29480.000000

# %%
data = data.drop(['Offence Group', 'Offence Subgroup', 'Offence Code'], axis=1)

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
data['Force Name'] = label_encoder.fit_transform(data['Force Name'])
data['Offence Description'] = label_encoder.fit_transform(data['Offence Description'])

# %%
data['Financial Year'] = data['Financial Year'].apply(lambda x: int(x.split('/')[0]))

# %%
# Save the transformed DataFrame to a new CSV file
data.to_csv('transformed_dataset.csv', index=False)

# %%
duplicate_rows = data[data.duplicated()]
print("Number of duplicate rows: ", duplicate_rows.shape[0])
# Out:
# Number of duplicate rows:  0

# %%
import pandas as pd

data = pd.read_csv('transformed_dataset.csv')


# Define training and testing periods
train_end_year = 2022
train_end_quarter = 1

# Split the dataset into training and test sets based on the condition
train_data = data[(data['Financial Year'] < train_end_year) | ((data['Financial Year'] == train_end_year) & (data['Financial Quarter'] <= train_end_quarter))]
test_data = data[(data['Financial Year'] > train_end_year) | ((data['Financial Year'] == train_end_year) & (data['Financial Quarter'] > train_end_quarter))]

# Optionally, save the split datasets
train_data.to_csv('train_dataset.csv', index=False)
test_data.to_csv('test_dataset.csv', index=False)

# %%
import pandas as pd

# Load the datasets
train_data = pd.read_csv('train_dataset.csv')
test_data = pd.read_csv('test_dataset.csv')

# Get the number of records in each dataset
num_records_train = train_data.shape[0]
num_records_test = test_data.shape[0]

# Print the number of records
print(f"Number of records in the training dataset: {num_records_train}")
print(f"Number of records in the test dataset: {num_records_test}")
# Out:
# Number of records in the training dataset: 75127
# Number of records in the test dataset: 23650
